# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\giovanni\appdata\local\python\pythoncore-3.14-64\lib\site-packages (3.0.3)
# Requirement already satisfied: numpy>=2.3.3 in c:\users\giovanni\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from pandas) (2.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\giovanni\appdata\roaming\python\python314\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\giovanni\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: six>=1.5 in c:\users\giovanni\appdata\roaming\python\python314\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

df = pd.Series([800, 900, 1000, 1100, 1200, 50000])

print(f"promedio {df.mean()}")
print(f"promedio {df.median()}")
# Out:
# promedio 9166.666666666666
# promedio 1050.0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt



n = 400

ciudades    = ["Buenos Aires", "Córdoba", "Rosario", "Mendoza"]
tipos       = ["Departamento", "Casa", "PH"]

df = pd.DataFrame({
    "ciudad":       np.random.choice(ciudades, n, p=[0.45, 0.25, 0.20, 0.10]),
    "tipo":         np.random.choice(tipos,    n, p=[0.55, 0.30, 0.15]),
    "ambientes":    np.random.choice([1, 2, 3, 4, 5], n, p=[0.10, 0.30, 0.35, 0.20, 0.05]),
    "superficie_m2":np.random.normal(75, 25, n).clip(25, 200).round(1),
    "antiguedad":   np.random.exponential(15, n).clip(0, 60).round(0).astype(int),
    "precio_usd":   np.random.lognormal(11.5, 0.5, n).round(-3).astype(int),
    "expensas_ars": np.random.normal(45000, 15000, n).clip(5000, 120000).round(-3).astype(int),
})

# Agregar algunos valores atípicos intencionales
df.loc[5,  "precio_usd"]   = 850000
df.loc[12, "precio_usd"]   = 920000
df.loc[200,"expensas_ars"] = 180000

df.to_csv("propiedades.csv", index=False)
print(f"Dataset creado: {len(df)} filas")
print(df.describe())
# Out:
# Dataset creado: 400 filas
#         ambientes  superficie_m2  antiguedad     precio_usd   expensas_ars
# count  400.000000      400.00000  400.000000     400.000000     400.000000
# mean     2.797500       76.05550   14.457500  114592.500000   44937.500000
# std      1.038842       24.85197   14.092362   77235.677108   16803.257643
# min      1.000000       25.00000    0.000000   29000.000000    5000.000000
# 25%      2.000000       58.57500    4.000000   72000.000000   34000.000000
# 50%      3.000000       74.70000   10.000000   96500.000000   45000.000000
# 75%      3.000000       92.70000   20.000000  137000.000000   53000.000000
# max      5.000000      152.00000   60.000000  920000.000000  180000.000000

# %%
df.describe()
# Out:
#         ambientes  superficie_m2  antiguedad     precio_usd   expensas_ars
# count  400.000000      400.00000  400.000000     400.000000     400.000000
# mean     2.797500       76.05550   14.457500  114592.500000   44937.500000
# std      1.038842       24.85197   14.092362   77235.677108   16803.257643
# min      1.000000       25.00000    0.000000   29000.000000    5000.000000
# 25%      2.000000       58.57500    4.000000   72000.000000   34000.000000
# 50%      3.000000       74.70000   10.000000   96500.000000   45000.000000
# 75%      3.000000       92.70000   20.000000  137000.000000   53000.000000
# max      5.000000      152.00000   60.000000  920000.000000  180000.000000

# %%
df["precio_usd"].std().round(1)
# Out:
# np.float64(77235.7)

# %%
df = pd.read_csv("propiedades.csv")

df["ciudad"].mode()
# Out:
# 0    Buenos Aires
# Name: ciudad, dtype: str
